# %%
from sklearn import tree
import pandas as pd
import os
from zipfile import ZipFile

# %%
i=("Data/stormdata.zip")

zf = ZipFile(i)
    
name = zf.namelist()[0]

print(name)

df = pd.read_csv(zf.open(name))
# Out:
# stormdata.csv

# %%
df.head()
# Out:
#   Start Date_st End Date_st Name_st State_st  Category_st  \
# 0     7/14/2019   7/16/2019   Barry     LA 2          2.0
# 1     7/15/2019   7/16/2019   Barry     LA 2          2.0
# 2     7/16/2019   7/16/2019   Barry     LA 2          2.0
# 3     7/13/2019   7/16/2019   Barry     LA 2          2.0
# 4     7/12/2019   7/16/2019   Barry     LA 2          2.0
#
#    Central Pressure_st  Max Wind (Kt)_st       Date  \
# 0                  993                90  7/14/2019
# 1                  993                90  7/15/2019
# 2                  993                90  7/16/2019
# 3                  993                90  7/13/2019
# 4                  993                90  7/12/2019
#
#                                             Location    MM  ... Longitude  \
# 0  208 NM West of Naples FL                      ...  Jul   ...    25.925
# 1  208 NM West of Naples FL                      ...  Jul   ...    25.925
# ...

# %%
len(df.index)
# Out:
# 106740

# %%
list(df.columns)
# Out:
# ['Start Date_st',
#  'End Date_st',
#  'Name_st',
#  'State_st',
#  'Category_st',
#  'Central Pressure_st',
#  'Max Wind (Kt)_st',
#  'Date',
#  'Location',
#  'MM',
#  'Sector',
#  'Station',
#  '#YY',
#  'APD(sec)',
#  'ATMP(Cel)',
#  'Hh',
#  'Min',
#  'D GST(m/s)',
#  'DEWP(Cel)',
#  'DPD(sec)',
#  'Longitude',
#  'Latitude',
#  'MWD(deg)',
#  'PRES(T hPa)',
#  'R WSP(T m/s)',
#  'TIDE(ft)',
#  'VIS(mi)',
#  'WDI deg',
#  'WTMP(Cel)',
#  'WVHT(m)']

# %%
target = df["Category_st"].astype(str)

# %%
data = df[["R WSP(T m/s)", "WTMP(Cel)", "WVHT(m)"]]
feature_names = data.columns
data.head()
# Out:
#    R WSP(T m/s)  WTMP(Cel)  WVHT(m)
# 0           6.0       28.6     99.0
# 1           5.7       28.9     99.0
# 2           6.4       29.4     99.0
# 3           8.6       29.4     99.0
# 4           8.4       29.7     99.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.80, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.4778902004871651

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5150014052838673

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.3787397704901473, 'R WSP(T m/s)'),
#  (0.34914193961111983, 'WTMP(Cel)'),
#  (0.272118289898733, 'WVHT(m)')]

# %%
i=("Data/aug2020_42003.zip")

zf = ZipFile(i)
    
name = zf.namelist()[0]

print(name)

df_test = pd.read_csv(zf.open(name))
# Out:
# aug2020_42003.csv

# %%
df_test.head()
# Out:
#    Station     Sector                   Location  Longitude  Latitude   #YY  \
# 0    42003  East GULF  208 NM West of Naples, FL     25.925   -85.615  2020
# 1    42003  East GULF  208 NM West of Naples, FL     25.925   -85.615  2020
# 2    42003  East GULF  208 NM West of Naples, FL     25.925   -85.615  2020
# 3    42003  East GULF  208 NM West of Naples, FL     25.925   -85.615  2020
# 4    42003  East GULF  208 NM West of Naples, FL     25.925   -85.615  2020
#
#     MM      Date  hh  mm  ...  Unnamed: 16374  Unnamed: 16375  Unnamed: 16376  \
# 0  Aug  2020-8-1   0   0  ...             NaN             NaN             NaN
# 1  Aug  2020-8-1   0  10  ...             NaN             NaN             NaN
# 2  Aug  2020-8-1   0  20  ...             NaN             NaN             NaN
# 3  Aug  2020-8-1   0  30  ...             NaN             NaN             NaN
# 4  Aug  2020-8-1   0  40  ...             NaN             NaN             NaN
#
# ...

# %%
list(df_test.columns)
# Out:
# ['Station',
#  'Sector',
#  'Location',
#  'Longitude',
#  'Latitude',
#  '#YY',
#  'MM',
#  'Date',
#  'hh',
#  'mm',
#  'WDI_deg',
#  'R WSP(T m/s)',
#  'D GST(m/s)',
#  'WVHT(m)',
#  'DPD(sec)',
#  'APD(sec)',
#  'MWD(deg)',
#  'PRES(T hPa)',
#  'ATMP(Cel)',
#  'WTMP(Cel)',
#  'DEWP(Cel)',
#  'VIS(mi)',
#  'TIDE(ft)',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
#  'Unnamed: 58',
#  'Unnamed: 59',
# ...

# %%
aug_24=df_test.loc[df_test["DD"]==24]
aug_24.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DD'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-eecf7dbd0143> in <module>
# ...

# %%
# Create an empty list 
test_values =[] 
  
# Iterate over each row 
for index, rows in aug_24.iterrows(): 
    # Create list for the current row 
    my_list =[rows.WSPD, rows.WTMP, rows.WVHT] 
      
    # append the list to the final list 
    test_values.append(my_list) 
  
# Print the list 
print(test_values)
# Out:
# [['6', 29.4, 99.0], ['6.2', 29.4, 99.0], ['6.3', 29.4, 99.0], ['5.9', 29.5, 99.0], ['5.6', 29.5, 2.03], ['5.6', 29.6, 99.0], ['5.5', 29.6, 99.0], ['5', 29.6, 99.0], ['4.4', 29.6, 99.0], ['6.5 1', 29.6, 99.0], ['9.1 1', 29.6, 1.94], ['9.5 1', 29.6, 99.0], ['9.4 1', 29.6, 99.0], ['9.3 1', 29.6, 99.0], ['9.4 1', 29.6, 99.0], ['9.1 1', 29.6, 99.0], ['9.4 1', 29.6, 1.82], ['9.3 1', 29.6, 99.0], ['9.3 1', 29.6, 99.0], ['8.7 1', 29.6, 99.0], ['8.7 1', 29.6, 99.0], ['8.5 1', 29.6, 99.0], ['8.9 1', 29.6, 1.76], ['8.6 1', 29.6, 99.0], ['8.6 1', 29.5, 99.0], ['8.8 1', 29.5, 99.0], ['9.2 1', 29.4, 99.0], ['9.0 1', 29.4, 99.0], ['9.1 1', 29.5, 1.64], ['8.9 1', 29.5, 99.0], ['9.2 1', 29.5, 99.0], ['8.7 1', 29.5, 99.0], ['9.0 1', 29.5, 99.0], ['8.8 1', 29.5, 99.0], ['8.6 1', 29.5, 1.65], ['8.6 1', 29.5, 99.0], ['8.5 1', 29.5, 99.0], ['8.2 1', 29.5, 99.0], ['8.4 1', 29.5, 99.0], ['7.8', 29.5, 99.0], ['7.8', 29.5, 1.49], ['7.7', 29.5, 99.0], ['7.8', 29.5, 99.0], ['7.5', 29.5, 99.0], ['7', 29.5, 99.0]
# ...

# %%
clf.predict(test_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-b6bd03ccc46e> in <module>
# ----> 1 clf.predict(test_values)
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     417         """
#     418         check_is_fitted(self)
# --> 419         X = self._validate_X_predict(X, check_input)
#     420         proba = self.tree_.predict(X)
#     421         n_samples = X.shape[0]
#
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     378         """Validate X whenever one tries to predict, apply, predict_proba"""
#     379         if check_input:
# --> 380             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     381             if issparse(X) and (X.indices.dtype != np.intc or
# ...
